# %% [markdown]
# ## Analyze and Model Wine Quality

# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
df = pd.read_csv("WineQT.csv")

# %%
df = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']]

# %%
df.rename(columns={'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity',
                   'citric acid':'citric_acid', 'residual sugar':'residual_sugar', 
                    'free sulfur dioxide':'free_sulfur_dioxide', 'total sulfur dioxide':'total_sulfur_dioxide'}, inplace=True)
# Out:
# /tmp/ipykernel_51384/953860565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'fixed acidity':'fixed_acidity', 'volatile acidity':'volatile_acidity',

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ### Scatter plot analysis of each feature

# %%
def make_scatter(data_frame):
    for col in data_frame.columns:
        plt.scatter(data_frame[col], data_frame["quality"])
        plt.xlabel(col)
        plt.ylabel("quality")
        plt.show()

make_scatter(df)

# %%
df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.250728     0.673157
# volatile_acidity          -0.250728          1.000000    -0.544187
# citric_acid                0.673157         -0.544187     1.000000
# residual_sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free_sulfur_dioxide       -0.164831         -0.001962    -0.057589
# total_sulfur_dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %% [markdown]
# ### Creating train and test dataset

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
train.shape
# Out:
# (915, 12)

# %%
test.shape
# Out:
# (228, 12)

# %% [markdown]
# ### Multiple Regression Model

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
x = np.asanyarray(train[['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar','chlorides', 
                         'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density','pH', 'sulphates', 'alcohol']])
y = np.asanyarray(train[['quality']])
regr.fit (x, y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ', regr.intercept_)
# Out:
# Coefficients:  [[ 2.17553097e-02 -1.14907677e+00 -8.17174289e-02  2.68250243e-02
#   -1.90485520e+00  2.86306447e-03 -2.86783731e-03 -2.06601627e+01
#   -4.41976574e-01  8.21518243e-01  2.63129024e-01]]
# Intercept:  [25.05776737]

# %% [markdown]
# ### Prediction

# %%
y_hat= regr.predict(test[['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar','chlorides', 
                         'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density','pH', 'sulphates', 'alcohol']])
x = np.asanyarray(test[['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar','chlorides', 
                         'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density','pH', 'sulphates', 'alcohol']])
y = np.asanyarray(test[['quality']])
print("Mean Squared Error (MSE) : %.2f"
      % np.mean((y_hat - y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x, y))
# Out:
# Mean Squared Error (MSE) : 0.47
# Variance score: 0.34
# /home/justin/.pyenv/versions/3.11.7/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Make Model using scikit-learn

# %%
from sklearn import preprocessing, svm
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import jaccard_score, f1_score, log_loss, confusion_matrix, accuracy_score, r2_score
import sklearn.metrics as metrics

# %% [markdown]
# ### Train and Test split

# %%
X = df[['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol']]
Y = df[['quality']]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %% [markdown]
# ### Fit the model

# %%
LinearReg = LinearRegression()
LinearReg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Prediction

# %%
predictions = LinearReg.predict(x_test)

# %% [markdown]
# ### calculate the value for each metric

# %%
LinearRegression_MAE = np.mean(np.absolute(predictions - y_test))
LinearRegression_MSE = np.mean((predictions - y_test) ** 2)
LinearRegression_R2 = r2_score(y_test, predictions)

# %%
Report = pd.DataFrame({"MAE": [LinearRegression_MAE], "MSE": [LinearRegression_MSE], "R2": [LinearRegression_R2] }, index=["LinearRegression"])
Report
# Out:
#                        MAE       MSE        R2
# LinearRegression  0.533102  0.465561  0.400401
